# %%
import pandas as pd
import glob


import os
from tqdm import tqdm
from sqlalchemy import create_engine, inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import sqlite3

# %% [markdown]
# ## Import all CSVs from 2020 - 2014 into a single DF.

# %%
# %%time

path = r'./data_airQA' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %% [markdown]
# ### Save to CSV

# %%
# frame.to_csv('data_airQA/aws_raw.csv')

# %% [markdown]
# ## Filter the raw data for Seattle and re-export as a CSV

# %%
# %%time

df = pd.read_csv("data_airQA/aws_raw.csv")

# %%
df.loc[df['city']=='Seattle-Tacoma-Bellevue']

# %%
# %%time

# Reference: https://pythondata.com/working-large-csv-files-python/

    
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! # ONE TIME process only! # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! #
                # Export CSV to a SQLITE DB, so that queries are manageable in-memory.
    

chunksize = 10 ** 6 # Chuncking the csv by 1 million rows per iterations

file = 'data_airQA/aws_raw.csv'

csv_database = create_engine('sqlite:///data_airQA.db') # Generated a 3.0GB file!

i = 0
j = 1
for df in tqdm(pd.read_csv(file, chunksize=chunksize, iterator=True)):
      df = df.rename(columns={c: c.replace(' ', '') for c in df.columns}) 
      df.index += j
      i+=1
      df.to_sql('table', csv_database, if_exists='append')
      j = df.index[-1] + 1
# Out:
# 0it [00:00, ?it/s]/home/hp-nunes/anaconda3/envs/TEST/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# 10it [07:12, 43.21s/it]
# CPU times: user 6min 42s, sys: 14.6 s, total: 6min 57s
# Wall time: 7min 12s

# %% [markdown]
# ### Filter the dataset to retain data solely for the Seattle area

# %%
df = df.loc[df['city']=='Seattle-Tacoma-Bellevue']

# %%
# df.to_csv('data_airQA/aws_Seattle.csv')

# %% [markdown]
# ## Wrangling the dataset

# %%
df_raw = pd.read_csv("data_airQA/aws_Seattle.csv")
# Out:
# /home/hp-nunes/anaconda3/envs/TEST/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(df_raw.shape)
print('-----------')
print(df_raw.dtypes)

df_raw.head()
# Out:
# (163916, 15)
# -----------
# Unnamed: 0           int64
# Unnamed:0            int64
# date                object
# parameter           object
# location            object
# value              float64
# unit                object
# city                object
# attribution         object
# averagingperiod     object
# coordinates         object
# country             object
# sourcename          object
# sourcetype          object
# mobile              object
# dtype: object
#    Unnamed: 0  Unnamed:0                                               date  \
# 0    54000009    9000008  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 1    54000016    9000015  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 2    54000025    9000024  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 3    54000026    9000025  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 4    54000036    9000035  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
#
#   parameter              location  value   unit                     city  \
# 0        o3   Mt Rainier- Jackson  0.043    ppm  Seattle-Tacoma-Bellevue
# 1        co   Seattle-Beacon Hill  0.170    ppm  Seattle-Tacoma-Bellevue
# 2        o3  Issaquah-Lake Sammam  0.039    ppm  Seattle-Tacoma-Bellevue
# 3        o3   Seattle-Beacon Hill  0.038    ppm  Seattle-Tacoma-Bellevue
# 4      pm25   Seattle-Beacon Hill  1.300  µg/m³  Seattle-Tacoma-Bellevue
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                    coordinates country sourcename sourcetype  \
# 0      {latitude=46.7841, longitude=-121.7403}      US     AirNow        NaN
# 1  {latitude=47.568237, longitude=-122.308624}      US     AirNow        NaN
# 2      {latitude=47.5525, longitude=-122.0647}      US     AirNow        NaN
# 3  {latitude=47.568237, longitude=-122.308624}      US     AirNow        NaN
# 4  {latitude=47.568237, longitude=-122.308624}      US     AirNow        NaN
#
#   mobile
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ### Retain the parameter for PM2.5

# %%
df = df_raw.loc[df_raw['parameter']=='pm25']
df = df.dropna(subset=['value'], how='all') # there were none


print(df.shape)
print('-----------')
print(str('We are left with ') + str(float((df.shape[0] / df_raw.shape[0])) * 100) + str('% of the raw dataset after parsing for PM2.5'))
df.head()
# Out:
# (163142, 15)
# -----------
# We are left with 99.52780692549842% of the raw dataset after parsing for PM2.5
#     Unnamed: 0  Unnamed:0                                               date  \
# 4     54000036    9000035  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 6     54000174    9000173  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 8     54002224    9002223  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 9     54002252    9002251  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
# 10    54002258    9002257  {utc=2016-05-29T19:00:00.000Z, local=2016-05-2...
#
#    parameter             location  value   unit                     city  \
# 4       pm25  Seattle-Beacon Hill    1.3  µg/m³  Seattle-Tacoma-Bellevue
# 6       pm25     Tacoma-S 36th St    4.0  µg/m³  Seattle-Tacoma-Bellevue
# 8       pm25       Lynnwood-212th    1.8  µg/m³  Seattle-Tacoma-Bellevue
# 9       pm25          Tacoma-L St    0.9  µg/m³  Seattle-Tacoma-Bellevue
# 10      pm25     Seattle-Duwamish    1.6  µg/m³  Seattle-Tacoma-Bellevue
#
#                                           attribution  \
# 4   [{name=US EPA AirNow, url=http://www.airnow.go...
# 6   [{name=US EPA AirNow, url=http://www.airnow.go...
# 8   [{name=US EPA AirNow, url=http://www.airnow.go...
# 9   [{name=US EPA AirNow, url=http://www.airnow.go...
# 10  [{name=US EPA AirNow, url=http://www.airnow.go...
#
#             averagingperiod                                  coordinates  \
# 4   {unit=hours, value=1.0}  {latitude=47.568237, longitude=-122.308624}
# 6   {unit=hours, value=1.0}    {latitude=47.22634, longitude=-122.46256}
# 8   {unit=hours, value=1.0}      {latitude=47.8064, longitude=-122.3167}
# 9   {unit=hours, value=1.0}      {latitude=47.1864, longitude=-122.4517}
# 10  {unit=hours, value=1.0}       {latitude=47.562, longitude=-122.3405}
#
#    country sourcename sourcetype mobile
# 4       US     AirNow        NaN    NaN
# 6       US     AirNow        NaN    NaN
# 8       US     AirNow        NaN    NaN
# 9       US     AirNow        NaN    NaN
# 10      US     AirNow        NaN    NaN

# %% [markdown]
# ### Extract Date (local time, not UTC) & set field to DateTime

# %%
df['year'] = df['date'].str.split('=').str[1].str.split('-').str[0]

df['date_drop'] =  df.date.str.split(', local=').str[1]
df['date'] = df['date_drop'].str.split('T').str[0]
df['hour'] = df['date_drop'].str.split('T').str[1]
df['hour'] = df['hour'].str.replace(r':00-08:00}', '')

df['dateTime'] = pd.to_datetime(df['date'] + ' ' + df['hour'])

# %%
### Split Latitude and Longitude into separate fields

df['Latitude'] = df.coordinates.str.split(', longitude=').str[0].str.replace(r'{latitude=', '')
df['Longitude'] = df.coordinates.str.split(', longitude=').str[1].str.replace(r'}', '')

# %%
# Reformat the attribution field 

df['attribution'] = 'US EPA AirNow, http://www.airnow.gov/, Washington Department of Ecology'

# %%
df = df.drop(['country','sourcename','sourcetype','mobile','coordinates',
              'averagingperiod','Unnamed: 0','Unnamed:0','date_drop'],axis=1)

# %%
print('Cleaned Master Dataset')
print('----------')
print(df.shape)
print('----------')
print(df.dtypes)

df.head()
# Out:
# Cleaned Master Dataset
# ----------
# (163142, 12)
# ----------
# date                   object
# parameter              object
# location               object
# value                 float64
# unit                   object
# city                   object
# attribution            object
# year                   object
# hour                   object
# dateTime       datetime64[ns]
# Latitude               object
# Longitude              object
# dtype: object
#           date parameter             location  value   unit  \
# 4   2016-05-29      pm25  Seattle-Beacon Hill    1.3  µg/m³
# 6   2016-05-29      pm25     Tacoma-S 36th St    4.0  µg/m³
# 8   2016-05-29      pm25       Lynnwood-212th    1.8  µg/m³
# 9   2016-05-29      pm25          Tacoma-L St    0.9  µg/m³
# 10  2016-05-29      pm25     Seattle-Duwamish    1.6  µg/m³
#
#                        city  \
# 4   Seattle-Tacoma-Bellevue
# 6   Seattle-Tacoma-Bellevue
# 8   Seattle-Tacoma-Bellevue
# 9   Seattle-Tacoma-Bellevue
# 10  Seattle-Tacoma-Bellevue
#
#                                           attribution  year   hour  \
# 4   US EPA AirNow, http://www.airnow.gov/, Washing...  2016  11:00
# 6   US EPA AirNow, http://www.airnow.gov/, Washing...  2016  11:00
# 8   US EPA AirNow, http://www.airnow.gov/, Washing...  2016  11:00
# 9   US EPA AirNow, http://www.airnow.gov/, Washing...  2016  11:00
# 10  US EPA AirNow, http://www.airnow.gov/, Washing...  2016  11:00
#
#               dateTime   Latitude    Longitude
# 4  2016-05-29 11:00:00  47.568237  -122.308624
# 6  2016-05-29 11:00:00   47.22634   -122.46256
# 8  2016-05-29 11:00:00    47.8064    -122.3167
# 9  2016-05-29 11:00:00    47.1864    -122.4517
# 10 2016-05-29 11:00:00     47.562    -122.3405

# %% [markdown]
# ### Save cleaned 'MasterDataset' to CSV

# %%
# df.to_csv('data_airQA/aws_Seattle_clean.csv')

# %% [markdown]
# ### Set the Date and Time as the dataframe's index, and sort the dataframe chronologically

# %%
df = df.sort_values(by='dateTime')
df.set_index(['dateTime'], inplace = True)

# %%
print('The dataframe ranges from 2016-03-14 21:00:00 to 2020-05-29 17:00:00')

df.head()
# Out:
# The dataframe ranges from 2016-03-14 21:00:00 to 2020-05-29 17:00:00
#                            date parameter              location  value   unit  \
# dateTime
# 2016-03-14 21:00:00  2016-03-14      pm25     Puyallup-128th St    0.8  µg/m³
# 2016-03-14 21:00:00  2016-03-14      pm25    Seattle-South Park    4.5  µg/m³
# 2016-03-14 21:00:00  2016-03-14      pm25  Bellevue-Bellevue Wa    0.7  µg/m³
# 2016-03-14 21:00:00  2016-03-14      pm25     Darrington-Fir St    6.0  µg/m³
# 2016-03-14 21:00:00  2016-03-14      pm25      Tacoma-S 36th St    2.0  µg/m³
#
#                                         city  \
# dateTime
# 2016-03-14 21:00:00  Seattle-Tacoma-Bellevue
# 2016-03-14 21:00:00  Seattle-Tacoma-Bellevue
# 2016-03-14 21:00:00  Seattle-Tacoma-Bellevue
# 2016-03-14 21:00:00  Seattle-Tacoma-Bellevue
# 2016-03-14 21:00:00  Seattle-Tacoma-Bellevue
#
#                                                            attribution  year  \
# dateTime
# 2016-03-14 21:00:00  US EPA AirNow, http://www.airnow.gov/, Washing...  2016
# 2016-03-14 21:00:00  US EPA AirNow, http://www.airnow.gov/, Washing...  2016
# 2016-03-14 21:00:00  US EPA AirNow, http://www.airnow.gov/, Washing...  2016
# 2016-03-14 21:00:00  US EPA AirNow, http://www.airnow.gov/, Washing...  2016
# 2016-03-14 21:00:00  US EPA AirNow, http://www.airnow.gov/, Washing...  2016
#
#                       hour  Latitude   Longitude
# dateTime
# 2016-03-14 21:00:00  21:00   47.1405   -122.2992
# 2016-03-14 21:00:00  21:00   47.5309   -122.3208
# 2016-03-14 21:00:00  21:00    47.613   -122.2017
# 2016-03-14 21:00:00  21:00   48.2468   -121.6031
# 2016-03-14 21:00:00  21:00  47.22634  -122.46256

# %% [markdown]
# ## Timeseries

# %%
df_plot = df.groupby(['Latitude','Longitude','location','date','year','dateTime']).mean().reset_index()

df_20 = df_plot[df_plot['year']=='2020']
df_20.set_index(['dateTime'], inplace = True)
df_20 = df_20.resample('D').mean()
# df_20['time'] = df_20.index.strftime('%m-%d')
# df_20 = df_20.reset_index()

df_19 = df_plot[df_plot['year']=='2019']
df_19.set_index(['dateTime'], inplace = True)
df_19 = df_19.resample('D').mean()
# df_19['time'] = df_19.index.strftime('%m-%d')
# df_19 = df_19.reset_index()


df_18 = df_plot[df_plot['year']=='2018']
df_18.set_index(['dateTime'], inplace = True)
df_18 = df_18.resample('D').mean()
# df_18['time'] = df_18.index.strftime('%m-%d')
# df_18 = df_18.reset_index()

df_17 = df_plot[df_plot['year']=='2017']
df_17.set_index(['dateTime'], inplace = True)
df_17 = df_17.resample('D').mean()
# df_17['time'] = df_17.index.strftime('%m-%d')
# df_17 = df_17.reset_index()

df_16 = df_plot[df_plot['year']=='2016']
df_16.set_index(['dateTime'], inplace = True)
df_16 = df_16.resample('D').mean()
# df_16['time'] = df_16.index.strftime('%m-%d')
# df_16 = df_16.reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import *
from matplotlib import *

plt.figure(figsize=(20,13))
with plt.xkcd():
    sns.set_style('darkgrid')
    sns.lineplot(x=df_20.index, y= df_20.value, marker='o',alpha=1, color='blue')
    sns.lineplot(x=df_19.index, y= df_19.value, marker='o',alpha=1, color='green')
    sns.lineplot(x=df_18.index, y= df_18.value, marker='o',alpha=1, color='red')
    sns.lineplot(x=df_17.index, y= df_17.value, marker='o',alpha=1, color='orange')
    sns.lineplot(x=df_16.index, y= df_16.value, marker='o',alpha=1, color='purple')

    ax = pylab.axes()
    ax.set_title("PM2.5 Measurements, Seattle Metro Area, Jan. - May")

    ax.set_ylabel('µg/m³')
    ax.set_xlabel('Time of Measurement')
# Out:
# /home/hp-nunes/anaconda3/envs/TEST/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
